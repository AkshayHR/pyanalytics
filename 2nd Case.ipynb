# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import datetime as dt 
import os

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '2nd Case.ipynb',
#  'Case Study 1.ipynb',
#  'D1-datastuctures.ipynb',
#  'D2_datastructures.ipynb',
#  'data',
#  'Doubts.ipynb',
#  'NP and PD.ipynb',
#  'Practice.ipynb',
#  'Practicemit.xlsx',
#  'Set Practice.ipynb',
#  'Tuple Practice.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
df=pd.read_excel('Practicemit.xlsx')

# %%
df
# Out:
#    MIT On Contract MIS      Unnamed: 1                      Unnamed: 2  \
# 0                Sr.No  Employee code             Name of the Employee
# 1                    1              29          Dr. Ashwini L. Bargaje
# 2                    2              25           Mr. Pratap V.Khedkar
# 3                    3              27         Mr. Shivdatta P. Gholap
# 4                    4              30             Dr. Akshay W. Sonar
# 5                    5              23           Dr. Akshay M. Jadhav
# 6                    6              23       Dr. Anuradha R. Deshmukh
# 7                    7              25           Dr. Mahesh A. Mandora
# 8                    8              28              Dr. Nitin K. Mothe
# 9                    9              27            Dr. Pooja B.Kathore
# 10                  10              24               Dr. Uzma Phopere
# 11                  11              26             Dr. Varsha M. Pawar
# ...

# %%
df.head(2)
# Out:
#   MIT On Contract MIS      Unnamed: 1              Unnamed: 2  \
# 0               Sr.No  Employee code     Name of the Employee
# 1                   1              29  Dr. Ashwini L. Bargaje
#
#             Unnamed: 3  Unnamed: 4 2022-08-01 00:00:00           Unnamed: 6  \
# 0         Designation   Department            Category                  DOJ
# 1  Clinical Assistant     Medical                 RMO   2020-04-12 00:00:00
#
#             Unnamed: 7 Unnamed: 8  Unnamed: 9     Unnamed: 10  Unnamed: 11  \
# 0      End of Contract    Salary          DOB  Qualification   Expiriance
# 1  2023-04-11 00:00:00      21000  11.07.1995            BHMS       2Years
#
#         Unnamed: 12                 Unnamed: 13 Unnamed: 14
# 0  Registration No.  Registration No. Validity      Remarks
# 1             75634                         NaN         NaN

# %%
df.columns
# Out:
# Index(['MIT On Contract MIS',          'Unnamed: 1',          'Unnamed: 2',
#                 'Unnamed: 3',          'Unnamed: 4',   2022-08-01 00:00:00,
#                 'Unnamed: 6',          'Unnamed: 7',          'Unnamed: 8',
#                 'Unnamed: 9',         'Unnamed: 10',         'Unnamed: 11',
#                'Unnamed: 12',         'Unnamed: 13',         'Unnamed: 14'],
#       dtype='object')

# %%
df=pd.read_excel('Practicemit.xlsx')

# %%
df
# Out:
#     Sr.No  Employee code             Name of the Employee  \
# 0       1              29          Dr. Ashwini L. Bargaje
# 1       2              25           Mr. Pratap V.Khedkar
# 2       3              27         Mr. Shivdatta P. Gholap
# 3       4              30             Dr. Akshay W. Sonar
# 4       5              23           Dr. Akshay M. Jadhav
# 5       6              23       Dr. Anuradha R. Deshmukh
# 6       7              25           Dr. Mahesh A. Mandora
# 7       8              28              Dr. Nitin K. Mothe
# 8       9              27            Dr. Pooja B.Kathore
# 9      10              24               Dr. Uzma Phopere
# 10     11              26             Dr. Varsha M. Pawar
# 11     12              26              Mr. Bhushan Joshi
# 12     13              29                Ms. Zarin Ramani
# 13     14              28      Mr. Shrikrushna B. Kokate
# 14     15              24               Mr. Sandeep Giri
# ...

# %%
df.columns
# Out:
# Index(['Sr.No', 'Employee code ', 'Name of the Employee', 'Designation ',
#        'Department', 'Category', 'DOJ', 'End of Contract', 'Salary ', 'DOB',
#        'Qualification ', 'Expiriance ', 'Registration No.',
#        'Registration No. Validity ', 'Remarks'],
#       dtype='object')

# %% [markdown]
# - Changing the name of columns in a shorter form

# %%
newCol = ['ser','empID','empName','design','dept','category','DOJ','DOL','salary','DOB','qualification','exp','regdNo','regdVal','remarks']

# %%
len(newCol)
# Out:
# 15

# %%
df.shape #No of rows & Columns
# Out:
# (32, 15)

# %%
df.describe() #Describe about the newuric columns - Mean, Min, Max
# Out:
#            Sr.No  Employee code                   DOJ      End of Contract  \
# count  32.000000       32.000000                   32                   32
# mean   16.500000       30.593750  2022-02-18 17:15:00  2023-03-24 01:30:00
# min     1.000000       21.000000  2020-04-12 00:00:00  2022-06-30 00:00:00
# 25%     8.750000       25.750000  2022-01-01 00:00:00  2022-12-31 00:00:00
# 50%    16.500000       29.500000  2022-04-27 12:00:00  2023-04-30 00:00:00
# 75%    24.250000       35.250000  2022-06-01 00:00:00  2023-05-31 00:00:00
# max    32.000000       43.000000  2022-08-01 00:00:00  2023-12-31 00:00:00
# std     9.380832        6.308516                  NaN                  NaN
#
#             Salary   Remarks
# count     32.000000      0.0
# mean   22000.000000      NaN
# min    15000.000000      NaN
# 25%    16500.000000      NaN
# 50%    18600.000000      NaN
# 75%    22000.000000      NaN
# max    65000.000000      NaN
# std    10553.122149      NaN

# %%
df.describe(include='all')
# Out:
#             Sr.No  Employee code     Name of the Employee  \
# count   32.000000       32.000000                      32
# unique        NaN             NaN                      32
# top           NaN             NaN  Dr. Ashwini L. Bargaje
# freq          NaN             NaN                       1
# mean    16.500000       30.593750                     NaN
# min      1.000000       21.000000                     NaN
# 25%      8.750000       25.750000                     NaN
# 50%     16.500000       29.500000                     NaN
# 75%     24.250000       35.250000                     NaN
# max     32.000000       43.000000                     NaN
# std      9.380832        6.308516                     NaN
#
#                Designation  Department Category                  DOJ  \
# count                    32         32       32                   32
# unique                   12          9        9                  NaN
# ...

# %%
df.dtypes #Datatypes
# Out:
# Sr.No                                  int64
# Employee code                          int64
# Name of the Employee                  object
# Designation                           object
# Department                            object
# Category                              object
# DOJ                           datetime64[ns]
# End of Contract               datetime64[ns]
# Salary                                 int64
# DOB                                   object
# Qualification                         object
# Expiriance                            object
# Registration No.                      object
# Registration No. Validity             object
# Remarks                              float64
# dtype: object

# %%
df[['empID','DOB']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df[['empID','DOB']]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# ...

# %%
newCol
# Out:
# ['ser',
#  'empID',
#  'empName',
#  'design',
#  'dept',
#  'category',
#  'DOJ',
#  'DOL',
#  'salary',
#  'DOB',
#  'qualification',
#  'exp',
#  'regdNo',
#  'regdVal',
#  'remarks']

# %%
df.dtypes
# Out:
# Sr.No                                  int64
# Employee code                          int64
# Name of the Employee                  object
# Designation                           object
# Department                            object
# Category                              object
# DOJ                           datetime64[ns]
# End of Contract               datetime64[ns]
# Salary                                 int64
# DOB                                   object
# Qualification                         object
# Expiriance                            object
# Registration No.                      object
# Registration No. Validity             object
# Remarks                              float64
# dtype: object

# %%
df['Designation','Expiriance']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Designation', 'Expiriance')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['DOB'].head()
# Out:
# 0    11.07.1995
# 1    14.11.1979
# 2    18.12.1988
# 3    09.05.1997
# 4    14.10.1996
# Name: DOB, dtype: object

# %%
df['DOB'] = pd.to_datetime(df['DOB'],format= %d.%m.%Y)
# Out:
#   Cell In[31], line 1
#     df['DOB'] = pd.to_datetime(df['DOB'],format= %d.%m.%Y)
#                                                  ^
# SyntaxError: invalid syntax

# %%
df['DOB'] = pd.to_datetime(df['DOB'], format='%d.%m.%Y') # To change date format

# %%
df['Registration No. Validity'] = pd.to_datetime(df['Registration No. Validity'], format='%d.%m.%Y')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Registration No. Validity'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.columns
# Out:
# Index(['Sr.No', 'Employee code ', 'Name of the Employee', 'Designation ',
#        'Department', 'Category', 'DOJ', 'End of Contract', 'Salary ', 'DOB',
#        'Qualification ', 'Expiriance ', 'Registration No.',
#        'Registration No. Validity ', 'Remarks'],
#       dtype='object')

# %%
df.Salary.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11836\2368074359.py in ?()
# ----> 1 df.Salary.hist()
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Salary'

# %%
df['Salary '].hist() - FindError
# Out:
# <Axes: >

# %%
df['Salary '].plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11836\445398900.py in ?()
# ----> 1 df['Salary '].plt.show()
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'plt'

# %%
df['Salary '].plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11836\445398900.py in ?()
# ----> 1 df['Salary '].plt.show()
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'plt'

# %%
plt.bar(df['Salary '], df['DOJ']) # Explannation
# Out:
# <BarContainer object of 32 artists>
